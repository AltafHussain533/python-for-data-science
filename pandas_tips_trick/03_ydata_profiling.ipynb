# %% [markdown]
# # Automatic EDA using `ydata_profiling`

# %%
pip install ydata -profiling
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [optparse.groups]Usage:[/]
#   c:\Users\Hair\AppData\Local\miniconda3\envs\ydata_profiling\python.exe -m pip install \[options] <requirement specifier> \[package-index-options] ...
#   c:\Users\Hair\AppData\Local\miniconda3\envs\ydata_profiling\python.exe -m pip install \[options] -r <requirements file> \[package-index-options] ...
#   c:\Users\Hair\AppData\Local\miniconda3\envs\ydata_profiling\python.exe -m pip install \[options] [-e] <vcs project url> ...
#   c:\Users\Hair\AppData\Local\miniconda3\envs\ydata_profiling\python.exe -m pip install \[options] [-e] <local project path> ...
#   c:\Users\Hair\AppData\Local\miniconda3\envs\ydata_profiling\python.exe -m pip install \[options] <archive url/path> ...
#
# no such option: -p

# %%
# improt libraries
import pandas as pd
import seaborn as sns
import ydata_profiling as yd

# %%
# import data from seaborn
df = sns.load_dataset('titanic')

# %%
# ydata profile report
profile = yd.ProfileReport(df)
profile.to_file(output_file='./outputs/03_ydata_titanic.html')

# %% [markdown]
# # Do it on our Pak Polulation Dataset

# %%
df_pop = pd.read_csv("./data/data.csv")

# %%
# ydata profile report
profile = yd.ProfileReport(df_pop)
profile.to_file(output_file='./outputs/03b_ydata_pak_poluation.html')
